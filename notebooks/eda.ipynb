# %%
import pandas as pd
import seaborn as sns

from pathlib import Path

# %%
silver_path = Path("../data/silver/bank_marketing_silver.csv")

df = pd.read_csv(silver_path, sep=";")

df.head()
# Out:
#    age        job  marital    education  default housing loan    contact  \
# 0   56  housemaid  married     basic 4y       no      no   no  telephone
# 1   57   services  married  high school  unknown      no   no  telephone
# 2   37   services  married  high school       no     yes   no  telephone
# 3   40      admin  married     basic 6y       no      no   no  telephone
# 4   56   services  married  high school       no      no  yes  telephone
#
#   month day_of_week  ...  campaign  pdays  previous     poutcome emp.var.rate  \
# 0   may         mon  ...         1    999         0  nonexistent          1.1
# 1   may         mon  ...         1    999         0  nonexistent          1.1
# 2   may         mon  ...         1    999         0  nonexistent          1.1
# 3   may         mon  ...         1    999         0  nonexistent          1.1
# 4   may         mon  ...         1    999         0  nonexistent          1.1
#
# ...

# %% [markdown]
# # Análise Exploratória dos Dados (EDA)
#
# O objetivo desta etapa é compreender as características do dataset tratado na camada Silver, identificar padrões, avaliar a qualidade dos dados e levantar hipóteses que orientarão a construção da camada Gold, responsável pela preparação do conjunto de dados para treinamento do modelo de Machine Learning.

# %%
df.shape
# Out:
# (41176, 21)

# %% [markdown]
# O dataset possui aproximadamente 41 mil registros e 21 atributos, contendo variáveis demográficas, histórico de campanhas anteriores, informações econômicas e a variável alvo (y), que indica a contratação ou não do depósito a prazo.

# %%
df["y"].value_counts(normalize=True)
# Out:
# y
# no     0.887337
# yes    0.112663
# Name: proportion, dtype: float64

# %% [markdown]
# Observa-se um forte desbalanceamento entre as classes, indicando que a maioria dos clientes não aderiu ao produto financeiro. Esse comportamento deverá ser considerado durante o treinamento e avaliação dos modelos.

# %%
df["job"].value_counts()
# Out:
# job
# admin            10419
# blue collar       9253
# technician        6739
# services          3967
# management        2924
# retired           1718
# entrepreneur      1456
# self employed     1421
# housemaid         1060
# unemployed        1014
# student            875
# unknown            330
# Name: count, dtype: int64

# %% [markdown]
# A maior parte dos clientes pertence às categorias "admin.", "blue-collar" e "technician", indicando maior representatividade desses perfis profissionais na base.

# %%
df["education"].value_counts()
# Out:
# education
# university degree      12164
# high school             9512
# basic 9y                6045
# professional course     5240
# basic 4y                4176
# basic 6y                2291
# unknown                 1730
# illiterate                18
# Name: count, dtype: int64

# %%
df["contact"].value_counts()
# Out:
# contact
# cellular     26135
# telephone    15041
# Name: count, dtype: int64
